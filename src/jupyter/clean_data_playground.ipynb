# %%
import os
from bs4 import BeautifulSoup

# %%
notebook_dir = os.getcwd()
out_dir_notifications = os.path.abspath(os.path.join(notebook_dir,"..","..","data","notifications"))

# %%
import os
import sys

# Build an absolute path from this notebook's parent directory
module_path = os.path.abspath(os.path.join('..', ))

# Add to sys.path if not already present
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils.week_file_save import current_week_file

# %%
format = "csv"
file_path_notifications = current_week_file(out_dir_notifications,format)

# %%
file_path_notifications
# Out:
# 'C:\\Users\\VEDANG BARMAN\\Desktop\\Regulatory Compliance Agent\\data\\notifications\\2026-08-24.csv'

# %%
import pandas as pd

# %%
import json
in_dir_config_file = os.path.abspath(os.path.join(notebook_dir,"..","..","config.json"))
with open (in_dir_config_file) as file:
    config_data = json.load(file)
file_path = config_data["data_check"]["ref_file"]
notification_data = pd.read_csv(file_path)

# %%
notification_data
# Out:
#                                                title  \
# 0  Reserve Bank of India (Rural Co-operative Bank...
# 1  Reserve Bank of India (Urban Co-operative Bank...
# 2  Reserve Bank of India (Regional Rural Banks – ...
# 3  Reserve Bank of India (Local Area Banks – Inte...
# 4  Reserve Bank of India (Small Finance Banks – I...
# 5  Reserve Bank of India (Commercial Banks – Inte...
# 6  Reserve Bank of India (Rural Co-operative Bank...
# 7  Reserve Bank of India (Urban Co-operative Bank...
# 8  Reserve Bank of India (Regional Rural Banks – ...
# 9  Reserve Bank of India (Small Finance Banks – C...
#
#                                          description  \
# 0  <table width="100%" border="0" align="center" ...
# 1  <table width="100%" border="0" align="center" ...
# 2  <table width="100%" border="0" align="center" ...
# 3  <table width="100%" border="0" align="center" ...
# 4  <table width="100%" border="0" align="center" ...
# 5  <table width="100%" border="0" align="center" ...
# 6  <table width="100%" border="0" align="center" ...
# 7  <table width="100%" border="0" align="center" ...
# 8  <table width="100%" border="0" align="center" ...
# 9  <table width="100%" border="0" align="center" ...
#
#                                                 link  \
# 0  https://www.rbi.org.in/scripts/NotificationUse...
# 1  https://www.rbi.org.in/scripts/NotificationUse...
# 2  https://www.rbi.org.in/scripts/NotificationUse...
# 3  https://www.rbi.org.in/scripts/NotificationUse...
# 4  https://www.rbi.org.in/scripts/NotificationUse...
# 5  https://www.rbi.org.in/scripts/NotificationUse...
# 6  https://www.rbi.org.in/scripts/NotificationUse...
# 7  https://www.rbi.org.in/scripts/NotificationUse...
# 8  https://www.rbi.org.in/scripts/NotificationUse...
# 9  https://www.rbi.org.in/scripts/NotificationUse...
#
#                      pubDate
# 0  Tue, 25 Aug 2026 18:30:00
# 1  Tue, 25 Aug 2026 18:25:00
# 2  Tue, 25 Aug 2026 18:25:00
# 3  Tue, 25 Aug 2026 18:25:00
# 4  Tue, 25 Aug 2026 18:20:00
# 5  Tue, 25 Aug 2026 18:15:00
# 6  Tue, 25 Aug 2026 18:05:00
# 7  Tue, 25 Aug 2026 18:00:00
# 8  Tue, 25 Aug 2026 18:00:00
# 9  Tue, 25 Aug 2026 17:55:00

# %%
title = notification_data['title']
title
# Out:
# 0    Reserve Bank of India (Rural Co-operative Bank...
# 1    Reserve Bank of India (Urban Co-operative Bank...
# 2    Reserve Bank of India (Regional Rural Banks – ...
# 3    Reserve Bank of India (Local Area Banks – Inte...
# 4    Reserve Bank of India (Small Finance Banks – I...
# 5    Reserve Bank of India (Commercial Banks – Inte...
# 6    Reserve Bank of India (Rural Co-operative Bank...
# 7    Reserve Bank of India (Urban Co-operative Bank...
# 8    Reserve Bank of India (Regional Rural Banks – ...
# 9    Reserve Bank of India (Small Finance Banks – C...
# Name: title, dtype: str

# %%
notification_data.isnull().sum()
# Out:
# title          0
# description    0
# link           0
# pubDate        0
# dtype: int64

# %%
description = notification_data['description']
description
# Out:
# 0    <table width="100%" border="0" align="center" ...
# 1    <table width="100%" border="0" align="center" ...
# 2    <table width="100%" border="0" align="center" ...
# 3    <table width="100%" border="0" align="center" ...
# 4    <table width="100%" border="0" align="center" ...
# 5    <table width="100%" border="0" align="center" ...
# 6    <table width="100%" border="0" align="center" ...
# 7    <table width="100%" border="0" align="center" ...
# 8    <table width="100%" border="0" align="center" ...
# 9    <table width="100%" border="0" align="center" ...
# Name: description, dtype: str

# %%
link = notification_data['link']
link
# Out:
# 0    https://www.rbi.org.in/scripts/NotificationUse...
# 1    https://www.rbi.org.in/scripts/NotificationUse...
# 2    https://www.rbi.org.in/scripts/NotificationUse...
# 3    https://www.rbi.org.in/scripts/NotificationUse...
# 4    https://www.rbi.org.in/scripts/NotificationUse...
# 5    https://www.rbi.org.in/scripts/NotificationUse...
# 6    https://www.rbi.org.in/scripts/NotificationUse...
# 7    https://www.rbi.org.in/scripts/NotificationUse...
# 8    https://www.rbi.org.in/scripts/NotificationUse...
# 9    https://www.rbi.org.in/scripts/NotificationUse...
# Name: link, dtype: str

# %%
pubDate = notification_data['pubDate']
pubDate
# Out:
# 0    Tue, 25 Aug 2026 18:30:00
# 1    Tue, 25 Aug 2026 18:25:00
# 2    Tue, 25 Aug 2026 18:25:00
# 3    Tue, 25 Aug 2026 18:25:00
# 4    Tue, 25 Aug 2026 18:20:00
# 5    Tue, 25 Aug 2026 18:15:00
# 6    Tue, 25 Aug 2026 18:05:00
# 7    Tue, 25 Aug 2026 18:00:00
# 8    Tue, 25 Aug 2026 18:00:00
# 9    Tue, 25 Aug 2026 17:55:00
# Name: pubDate, dtype: str

# %%
pubDate[0]
# Out:
# 'Tue, 25 Aug 2026 18:30:00'

# %%
link[0]
# Out:
# 'https://www.rbi.org.in/scripts/NotificationUser.aspx?Id=13690&Mode=0'

# %%
flag = 0
if str(link[0]) == str(link[1]):
    flag = 1
flag
# Out:
# 0

# %%
import pandas as pd
from bs4 import BeautifulSoup

def clean_xml(xml_data):
    if pd.isna(xml_data) or not isinstance(xml_data, str):
        return xml_data
        
    soup = BeautifulSoup(xml_data, 'xml')
    clean_text = soup.get_text(separator=' ', strip=True)
    return clean_text


notification_data['clean_description'] = notification_data['description'].apply(clean_xml)

# View the first 5 rows to see if it worked
print(notification_data['clean_description'].iloc[0])
# Out:
# RBI/2026-27/248 DOR.SOG(SPE).REC.214/13.03.00/2026-27 August 25, 2026 Reserve Bank of India (Rural Co-operative Banks  Interest Rate on Deposits) Second Amendment Directions, 2026 Please refer to the Reserve Bank of India (Rural Co-operative Banks  Interest Rate on Deposits) Directions, 2025 (hereinafter referred to as Directions), dated November 28, 2025 (Updated as on June 17, 2026), wherein temporary withdrawal of the interest rate ceiling on fresh FCNR(B) deposits of 3-5 year tenors and restriction on interest rates on NRE deposits of 3 year and above tenors, including the deposits that are renewed upon maturity, have been provided with effect from June 17, 2026, for the period until September 30, 2026. On a review, it has been decided to amend the date September 30, 2026 to the date August 31, 2026 for the aforementioned temporary relaxation. 2. Accordingly, in exercise of the powers conferred by Section 35A read with Section 56 of the Banking Regulation Act,1949 and all other laws enabling the Reserve Bank India (RBI) in this regard, the RBI, being satisfied that it is necessary and expedient in public interest so to do, hereby, issues the Amendment Directions hereinafter specified. 3. These Amendment Directions shall be called the Reserve Bank of India (Rural Co-operative Banks  Interest Rate on Deposits) Second Amendment Directions, 2026. 4. These Amendment Directions shall come into force with immediate effect. 5. These Amendment Directions shall modify the Directions, as under: In paragraph 24(4) subscript (1), the phrase with effect from June 17, 2026, for the period until September 30, 2026 shall be substituted with with effect from June 17, 2026, for the period until August 31, 2026. In paragraph 29(7) subscript (2), the phrase with effect from June 17, 2026, for the period until September 30, 2026 shall be substituted with with effect from June 17, 2026, for the period until August 31, 2026. (Dr. Sudarsana Sahoo) Chief General Manager
