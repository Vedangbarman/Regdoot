# %%
import pandas as pd
import numpy as np 
import langchain

# %%
import os 
notebook_path = os.getcwd()
notifications = os.path.abspath(os.path.join(notebook_path,"..","..","Data","notification_historical","notification.jsonl"))

# %%
data = pd.read_json(notifications,lines = True)

# %%
data.head()
# Out:
#       id                                              title category  \
# 0  12925  Reserve Bank of India (Credit Information Comp...     NBFC
# 1  12926  Reserve Bank of India (Credit Information Comp...     NBFC
# 2  12927  Reserve Bank of India (Asset Reconstruction Co...     NBFC
# 3  12928  Reserve Bank of India (Asset Reconstruction Co...     NBFC
# 4  12929  Reserve Bank of India (Asset Reconstruction Co...     NBFC
#
#                                                  url  \
# 0  https://rbi.org.in/scripts/NotificationUser.as...
# 1  https://rbi.org.in/scripts/NotificationUser.as...
# 2  https://rbi.org.in/scripts/NotificationUser.as...
# 3  https://rbi.org.in/scripts/NotificationUser.as...
# 4  https://rbi.org.in/scripts/NotificationUser.as...
#
#                                                 text
# 0  RBI/DoR/2025-26/379\nDoR.ORG.REC.No.298/21-04-...
# 1  RBI/DOR/2025-26/378\nDOR.FIN.REC.No.297/20.16....
# 2  RBI/DOR/2025-26/377\nDOR.AML.REC.No.296/14.01....
# 3  RBI/DOR/2025-26/376\nDOR.FIN.REC.No.295/20-16-...
# 4  RBI/DOR/2025-26/375\nDOR.FIN.REC.No.294/20.16....

# %%
data.isnull().sum()
# Out:
# id          0
# title       0
# category    0
# url         0
# text        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        766 non-null    int64
#  1   title     766 non-null    str
#  2   category  766 non-null    str
#  3   url       766 non-null    str
#  4   text      766 non-null    str
# dtypes: int64(1), str(4)
# memory usage: 30.1 KB

# %%
pd.set_option('display.max_colwidth',50000)

# %%
data["text"].head(1)
# Out:
# 0    RBI/DoR/2025-26/379\nDoR.ORG.REC.No.298/21-04-158/2025-26\nNovember 28, 2025\nReserve Bank of India (Credit Information Companies – Managing Risks in Outsourcing) Directions, 2025\nTable of Contents\nChapter I – Preliminary\nA. Short Title and Commencement\nB. Applicability and Scope\nC. Definitions\nChapter II – Role of the Board\nA. Board-Approved Policy\nB. Key Responsibilities\nChapter III – Outsourcing of Information Technology (IT) Services\nA. Authorisation, Accountability, and Oversight\nB. Governance Framework\nB.1 Outsourcing Policy\nB.2 Role of Senior Management\nB.3 Role of IT Function\nC. Risk Management\nC.1 Risk Management Framework\nC.2 Confidentiality and Security of Information\nD. Outsourcing Process\nD.1 Service Provider Evaluation\nD.2 Outsourcing Agreement\nD.3 Monitoring and Control of Outsourced Services\nD.4 Inventory of Outsourced Services\nD.5 Business Continuity and Management of Disaster Recovery Plan\nD.6 Exit Strategy\nD.7 Termination\nE. Specific Outsourcing Arrangements\nE.1 Outsourcing within a Group / Conglomerate\nE.2 Offshore or Cross-Border outsourcing\nE.3 Outsourcing of Security Operations Centre (SOC)\nE.4 Usage of Cloud Computing Services\nF. Redressal of Grievances related to Outsourced Services\nChapter IV – Repeal and Other Provisions\nA. Repeal and Saving\nB. Application of other laws not barred\nC. Interpretations\nIn exercise of the powers conferred by Section 11 of the Credit Information Companies (Regulation) Act, 2005, and all other provisions / laws enabling the Reserve Bank of India (‘RBI’) in this regard, RBI being satisfied that it is necessary and expedient in the public interest so to do, hereby, issues the Directions hereinafter specified.\nChapter I – Preliminary\nA. Short Title and Commencement\n1. These Directions shall be called the Reserve Bank of India (Credit Information Companies - Managing Risks in Outsourcing) Directions, 2025.\n2. These Directions shall come into force with immediate effect.\nProvided that a Credit Information Company’s existing Information Technology (IT) outsourcing agreements regardless of whether they are due for renewal on or after the effective date of these Directions shall comply with the provisions of these Directions either at the time of renewal or by\nApril 10, 2026\n, whichever is earlier. However, the Credit Information Company’s new IT outsourcing agreements that come into force on or after the effective date of these Directions, shall comply with the provisions of these Directions from the date of agreement itself.\nProvided further that nothing in the preceding proviso shall be construed as permitting non-compliance with any other extant regulatory instructions or statutory requirements applicable to such arrangements.\nB. Applicability and Scope\n3. These Directions shall be applicable to Credit Information Companies as defined under clause (e) of Section 2 of the Credit Information Companies (Regulation) Act, 2005, hereinafter collectively referred to as ‘CICs’ and individually as a ‘CIC’.\n4. These Directions shall apply to a CIC’s material outsourcing of IT services, as defined in paragraph 6(3) of these Directions. In this context, ‘Outsourcing of IT Services’ shall include outsourcing of the following services:\n(i) IT infrastructure management, maintenance and support (hardware, software or firmware);\n(ii) network and security solutions, and maintenance (hardware, software or firmware);\n(iii) application development, maintenance and testing by Application Service Providers (ASPs) including ATM Switch ASPs;\n(iv) services and operations related to data centres;\n(v) cloud computing services;\n(vi) managed security services; and\n(vii) management of IT infrastructure and technology services associated with payment system ecosystem.\n5. These Directions shall not apply to the following services:\n(i) corporate internet banking services obtained by a CIC as a corporate customer or sub-member of another Regulated Ent ...
# Name: text, dtype: str

# %%
data["title"].head()
# Out:
# 0                                    Reserve Bank of India (Credit Information Companies – Managing Risks in Outsourcing) Directions, 2025
# 1                                      Reserve Bank of India (Credit Information Companies) Directions, 2025 (Updated as on July 01, 2026)
# 2           Reserve Bank of India (Asset Reconstruction Companies – Know Your Customer) Directions, 2025 (Updated as on December 29, 2025)
# 3            Reserve Bank of India (Asset Reconstruction Companies – Treatment of Wilful Defaulters and Large Defaulters) Directions, 2025
# 4    Reserve Bank of India (Asset Reconstruction Companies  – Credit Information Reporting) Directions, 2025 (Updated as on July 01, 2026)
# Name: title, dtype: str

# %%
keywords_non_inclusive = ["Asset Reconstruction Companies", "Credit Information Companies", "Rural Co-operative Banks","Banker and Debt Manager to Government","Banker to Governments and Banks","Consumer Education and Protection","Commercial Banks","Small Finance Banks","Payments Banks","Local Area Banks","Regional Rural Banks","Urban Co-operative Banks","All India Financial Institutions","Payments Banks","Local Area Banks","Payment and Settlement System","Issuer of Currency","Foreign Exchange Management","Financial Inclusion and Development","Financial Market"]
keywords_inclusive = ["Non-Banking Financial Companies"]

pattern_non_inclusive = '|'.join(keywords_non_inclusive)
pattern_inclusive = '|'.join(keywords_inclusive)

mask_inclusive = data["title"].str.contains(pattern_inclusive, case = False, na = False)
nbfc_circular = data[mask_inclusive]

other_circular = data[data["title"].str.contains(pattern_non_inclusive, case = False, na = False) == False]

pd.set_option('display.max_colwidth',500)

x = len(mask_other["title"])
print(x)
# Out:
# 182
